# %% [markdown]
# # Airplane Crashes (August 1918- September 2022) - Beginner Friendly EDA
#
#
# ## In Memory of Antonov AN-225 "Mriya" (1988-2022)
#
# ![26493353293_15c0ddceea_h.jpg](attachment:26493353293_15c0ddceea_h.jpg)
# (Photo credit: Pavel Vanka, licensed under CC BY-NC)
#
#
# *After scraping the Aviation accident rate by year and fatalities by year data off the Bureau of Aircraft Accidents Archives - B3A (a Geneva-based NGO) website to an Excel spreadsheet through Web Query, merged data using INDEX/MATCH functions.
#
# According to [B3A website](https://www.baaa-acro.com/about):
#
# *The B3A compiles statistics on aviation accidents where an aircraft suffered such damage that it is not in a position to be used anymore and that it is removed from service (withdrawn from use, written off). The NGO only considers crashes involving an aircraft certified to carry at least 6 people, crew included (except for the early years), excluding helicopters, balloons, hot air balloons, airships, gliders, fighters, and all other aircraft which does not correspond to the criterias mentioned here above. In military aviation, only are considered accidents involving aircraft intended for troop transport, reconnaissance, surveillance, medium and heavy bomber and logistical support.
#
# **A Reminder > According to The Week's [Fact check: is flying safe?](https://www.theweek.co.uk/97155/fact-check-is-flying-safe)
#
# ***You are far more likely to die driving to the airport than you are to be involved in a deadly plane accident, the evidence suggests. A Harvard University study found that the odds that your airplane will crash are one in 1.2 million, and the odds of dying from a crash are one in 11 million.

# %% [markdown]
# ## Let's start with importing essential libraries.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Getting familiar with data

# %%
df =  pd.read_csv('Aircrash_Sencer.csv')

df.head()
# Out:
#    Year  Nb of Crashes  Fatalities
# 0  1918             25          29
# 1  1919             83          50
# 2  1920            127          77
# 3  1921            138          78
# 4  1922            106         105

# %%
df.tail(20).style.background_gradient(subset=["Nb of Crashes", "Fatalities"], cmap='flare')
# Out:
# <style type="text/css">
# #T_e2ac5_row0_col1, #T_e2ac5_row2_col2 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_e2ac5_row0_col2, #T_e2ac5_row1_col1, #T_e2ac5_row4_col1 {
#   background-color: #752d6f;
#   color: #f1f1f1;
# }
# #T_e2ac5_row1_col2, #T_e2ac5_row15_col1 {
#   background-color: #d14a61;
#   color: #f1f1f1;
# }
# #T_e2ac5_row2_col1 {
#   background-color: #5e2868;
#   color: #f1f1f1;
# }
# #T_e2ac5_row3_col1, #T_e2ac5_row5_col1 {
#   background-color: #5d2868;
#   color: #f1f1f1;
# }
# #T_e2ac5_row3_col2 {
#   background-color: #692b6c;
#   color: #f1f1f1;
# }
# #T_e2ac5_row4_col2 {
#   background-color: #a8396e;
#   color: #f1f1f1;
# }
# #T_e2ac5_row5_col2 {
#   background-color: #bb3f6a;
#   color: #f1f1f1;
# }
# #T_e2ac5_row6_col1 {
#   background-color: #893171;
#   color: #f1f1f1;
# }
# #T_e2ac5_row6_col2 {
#   background-color: #923371;
#   color: #f1f1f1;
# }
# #T_e2ac5_row7_col1 {
#   background-color: #802f70;
#   color: #f1f1f1;
# }
# #T_e2ac5_row7_col2 {
#   background-color: #8b3271;
#   color: #f1f1f1;
# }
# #T_e2ac5_row8_col1 {
#   background-color: #8c3271;
#   color: #f1f1f1;
# }
# #T_e2ac5_row8_col2 {
#   background-color: #c84365;
#   color: #f1f1f1;
# }
# #T_e2ac5_row9_col1 {
#   background-color: #8f3371;
#   color: #f1f1f1;
# }
# #T_e2ac5_row9_col2 {
#   background-color: #cf4862;
#   color: #f1f1f1;
# }
# #T_e2ac5_row10_col1 {
#   background-color: #963570;
#   color: #f1f1f1;
# }
# #T_e2ac5_row10_col2 {
#   background-color: #e98b6a;
#   color: #f1f1f1;
# }
# #T_e2ac5_row11_col1 {
#   background-color: #9f376f;
#   color: #f1f1f1;
# }
# #T_e2ac5_row11_col2 {
#   background-color: #642a6a;
#   color: #f1f1f1;
# }
# #T_e2ac5_row12_col1 {
#   background-color: #943471;
#   color: #f1f1f1;
# }
# #T_e2ac5_row12_col2 {
#   background-color: #b63d6b;
#   color: #f1f1f1;
# }
# #T_e2ac5_row13_col1 {
#   background-color: #b43d6b;
#   color: #f1f1f1;
# }
# #T_e2ac5_row13_col2 {
#   background-color: #e1645c;
#   color: #f1f1f1;
# }
# #T_e2ac5_row14_col1 {
#   background-color: #d34c60;
#   color: #f1f1f1;
# }
# #T_e2ac5_row14_col2 {
#   background-color: #eb9872;
#   color: #000000;
# }
# #T_e2ac5_row15_col2 {
#   background-color: #a2386f;
#   color: #f1f1f1;
# }
# #T_e2ac5_row16_col1 {
#   background-color: #bf4069;
#   color: #f1f1f1;
# }
# #T_e2ac5_row16_col2 {
#   background-color: #e5705e;
#   color: #f1f1f1;
# }
# #T_e2ac5_row17_col1, #T_e2ac5_row18_col1 {
#   background-color: #e0605c;
#   color: #f1f1f1;
# }
# #T_e2ac5_row17_col2 {
#   background-color: #e98768;
#   color: #f1f1f1;
# }
# #T_e2ac5_row18_col2 {
#   background-color: #ea9671;
#   color: #f1f1f1;
# }
# #T_e2ac5_row19_col1, #T_e2ac5_row19_col2 {
#   background-color: #edb081;
#   color: #000000;
# }
# </style>
# <table id="T_e2ac5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2ac5_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_e2ac5_level0_col1" class="col_heading level0 col1" >Nb of Crashes</th>
#       <th id="T_e2ac5_level0_col2" class="col_heading level0 col2" >Fatalities</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2ac5_level0_row0" class="row_heading level0 row0" >85</th>
#       <td id="T_e2ac5_row0_col0" class="data row0 col0" >2003</td>
#       <td id="T_e2ac5_row0_col1" class="data row0 col1" >225</td>
#       <td id="T_e2ac5_row0_col2" class="data row0 col2" >1260</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row1" class="row_heading level0 row1" >86</th>
#       <td id="T_e2ac5_row1_col0" class="data row1 col0" >2004</td>
#       <td id="T_e2ac5_row1_col1" class="data row1 col1" >195</td>
#       <td id="T_e2ac5_row1_col2" class="data row1 col2" >795</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row2" class="row_heading level0 row2" >87</th>
#       <td id="T_e2ac5_row2_col0" class="data row2 col0" >2005</td>
#       <td id="T_e2ac5_row2_col1" class="data row2 col1" >211</td>
#       <td id="T_e2ac5_row2_col2" class="data row2 col2" >1478</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row3" class="row_heading level0 row3" >88</th>
#       <td id="T_e2ac5_row3_col0" class="data row3 col0" >2006</td>
#       <td id="T_e2ac5_row3_col1" class="data row3 col1" >212</td>
#       <td id="T_e2ac5_row3_col2" class="data row3 col2" >1322</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row4" class="row_heading level0 row4" >89</th>
#       <td id="T_e2ac5_row4_col0" class="data row4 col0" >2007</td>
#       <td id="T_e2ac5_row4_col1" class="data row4 col1" >195</td>
#       <td id="T_e2ac5_row4_col2" class="data row4 col2" >1008</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row5" class="row_heading level0 row5" >90</th>
#       <td id="T_e2ac5_row5_col0" class="data row5 col0" >2008</td>
#       <td id="T_e2ac5_row5_col1" class="data row5 col1" >212</td>
#       <td id="T_e2ac5_row5_col2" class="data row5 col2" >916</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row6" class="row_heading level0 row6" >91</th>
#       <td id="T_e2ac5_row6_col0" class="data row6 col0" >2009</td>
#       <td id="T_e2ac5_row6_col1" class="data row6 col1" >182</td>
#       <td id="T_e2ac5_row6_col2" class="data row6 col2" >1120</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row7" class="row_heading level0 row7" >92</th>
#       <td id="T_e2ac5_row7_col0" class="data row7 col0" >2010</td>
#       <td id="T_e2ac5_row7_col1" class="data row7 col1" >188</td>
#       <td id="T_e2ac5_row7_col2" class="data row7 col2" >1153</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row8" class="row_heading level0 row8" >93</th>
#       <td id="T_e2ac5_row8_col0" class="data row8 col0" >2011</td>
#       <td id="T_e2ac5_row8_col1" class="data row8 col1" >180</td>
#       <td id="T_e2ac5_row8_col2" class="data row8 col2" >850</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row9" class="row_heading level0 row9" >94</th>
#       <td id="T_e2ac5_row9_col0" class="data row9 col0" >2012</td>
#       <td id="T_e2ac5_row9_col1" class="data row9 col1" >178</td>
#       <td id="T_e2ac5_row9_col2" class="data row9 col2" >807</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row10" class="row_heading level0 row10" >95</th>
#       <td id="T_e2ac5_row10_col0" class="data row10 col0" >2013</td>
#       <td id="T_e2ac5_row10_col1" class="data row10 col1" >173</td>
#       <td id="T_e2ac5_row10_col2" class="data row10 col2" >465</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row11" class="row_heading level0 row11" >96</th>
#       <td id="T_e2ac5_row11_col0" class="data row11 col0" >2014</td>
#       <td id="T_e2ac5_row11_col1" class="data row11 col1" >167</td>
#       <td id="T_e2ac5_row11_col2" class="data row11 col2" >1352</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row12" class="row_heading level0 row12" >97</th>
#       <td id="T_e2ac5_row12_col0" class="data row12 col0" >2015</td>
#       <td id="T_e2ac5_row12_col1" class="data row12 col1" >175</td>
#       <td id="T_e2ac5_row12_col2" class="data row12 col2" >938</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row13" class="row_heading level0 row13" >98</th>
#       <td id="T_e2ac5_row13_col0" class="data row13 col0" >2016</td>
#       <td id="T_e2ac5_row13_col1" class="data row13 col1" >152</td>
#       <td id="T_e2ac5_row13_col2" class="data row13 col2" >647</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row14" class="row_heading level0 row14" >99</th>
#       <td id="T_e2ac5_row14_col0" class="data row14 col0" >2017</td>
#       <td id="T_e2ac5_row14_col1" class="data row14 col1" >129</td>
#       <td id="T_e2ac5_row14_col2" class="data row14 col2" >404</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row15" class="row_heading level0 row15" >100</th>
#       <td id="T_e2ac5_row15_col0" class="data row15 col0" >2018</td>
#       <td id="T_e2ac5_row15_col1" class="data row15 col1" >131</td>
#       <td id="T_e2ac5_row15_col2" class="data row15 col2" >1039</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row16" class="row_heading level0 row16" >101</th>
#       <td id="T_e2ac5_row16_col0" class="data row16 col0" >2019</td>
#       <td id="T_e2ac5_row16_col1" class="data row16 col1" >145</td>
#       <td id="T_e2ac5_row16_col2" class="data row16 col2" >588</td>
#     </tr>
#     <tr>
#       <th id="T_e2ac5_level0_row17" class="row_heading level

# %% [markdown]
# *2014 included the disappearance of flight MH370 over the Indian Ocean and the shootdown of flight MH17.

# %%
df.shape
# Out:
# (105, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           105 non-null    int64
#  1   Nb of Crashes  105 non-null    int64
#  2   Fatalities     105 non-null    int64
# dtypes: int64(3)
# memory usage: 2.6 KB

# %%
df.duplicated().value_counts() #See if there are any dublicated
# Out:
# False    105
# dtype: int64

# %%
df.isnull().sum() #Calculating missing values in rows
# Out:
# Year             0
# Nb of Crashes    0
# Fatalities       0
# dtype: int64

# %%
(df.astype(str) == 'nan').any()
# Out:
# Year             False
# Nb of Crashes    False
# Fatalities       False
# dtype: bool

# %% [markdown]
# *Not a single missing value!

# %%
df.describe().T
# Out:
#                count         mean         std     min     25%     50%     75%  \
# Year           105.0  1969.990476   30.454725  1918.0  1944.0  1970.0  1996.0
# Nb of Crashes  105.0   281.228571  151.297545    25.0   208.0   269.0   332.0
# Fatalities     105.0  1534.914286  999.675275    29.0   647.0  1585.0  2220.0
#
#                   max
# Year           2022.0
# Nb of Crashes   949.0
# Fatalities     4700.0

# %%
total = df.iloc[:, 1:3].sum()
print(total)
# Out:
# Nb of Crashes     29529
# Fatalities       161166
# dtype: int64

# %% [markdown]
# **As of the data extraction date of September 9, 2022, the total fatalities due to aviation accidents since 1918 is 161,166. The total number of incidents is 29,529

# %%
#Let's rename Year, Nb of Crashes and Fatalities columns with the year, incidents, fatalities

# %%
df.columns = ["year", "incidents", "fatalities"]
df.columns
# Out:
# Index(['year', 'incidents', 'fatalities'], dtype='object')

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize = (15,10))
g = sns.lineplot(x = df.year, y = df.incidents,
                 marker = "o", markerfacecolor = "red", markersize = 10)
plt.style.use('bmh')
plt.ylabel("Number of Crashes")
plt.xlabel("Year")
g.figure.suptitle("Number of Crashes by Year", fontsize = 15, color = "red");

# %% [markdown]
# We can see that peaks between 1940-1950 look scary. Of course there are some questions thats are wanted to be asked, like "does total number of passenger include military flights or just passenger?" so this plot is that an estimation.

# %%
plt.figure(figsize = (15,10))
g = sns.lineplot(x = df.year, y = df.fatalities,
                 marker = "o", markerfacecolor = "red", markersize = 10)

plt.ylabel("Number of Fatalities")
plt.xlabel("Year")
g.figure.suptitle("Number of Fatalities by Year", fontsize = 15, color = "red");

# %% [markdown]
# The plot above is similar to the previous plot. the peaks seem close to each other, so let's look at the rate of deaths to accidents.

# %%
df['Rate'] = df['fatalities'] / df['incidents']
df.Rate
# Out:
# 0      1.160000
# 1      0.602410
# 2      0.606299
# 3      0.565217
# 4      0.990566
#          ...
# 100    7.931298
# 101    4.055172
# 102    4.247788
# 103    3.663717
# 104    4.655738
# Name: Rate, Length: 105, dtype: float64

# %%
plt.figure(figsize=(15,6))
plt.subplot(1, 2, 1)
plt.fill_between(df.year, 'fatalities', data=df, color="skyblue", alpha=0.2)
plt.plot(df.year, 'fatalities', data=df, marker = ".", color="Slateblue", alpha=0.6, linewidth=1)
plt.fill_between(df.year, 'incidents', data=df, color="olive", alpha=0.2)
plt.plot(df.year, 'incidents', data=df, color="olive", marker = ".", alpha=0.6, linewidth=1)
plt.legend(fontsize=10)
plt.xlabel('Year', fontsize=10)
plt.title('Count', loc='Center', fontsize=14)

plt.subplot(1, 2, 2)
plt.plot(df.year, 'Rate', data=df, marker = ".", color = 'red', linewidth=1)
plt.xlabel('Year', fontsize=10)
plt.ylabel('Rate', fontsize=10)
plt.title('Fatalities / Incidents by Year', loc='Center', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Fatalities / Incidents  early 60s, early 90s and early 2010s look scary, while ratio actually trends down.

# %% [markdown]
# ## Operators Analysis

# %% [markdown]
# Let's try to read in my csv file not in UTF-8 after scraping the death rate per operator data off the B3A.

# %%
operators = pd.read_csv('C:/Users/User/Downloads/Aircrash_Operators1.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 operators = pd.read_csv('C:/Users/User/Downloads/Aircrash_Operators1.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1235, in TextFileReader._make_engine(self, f, engine)
#    1232     raise ValueError(msg)
#    1234 try:
# -> 1235     return mapping[engine](f, **self.options)
#    1236 except Exception:
#    1237     if self.handles is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 493: invalid continuation byte

# %% [markdown]
# ## UTF-8 encoding

# %%
import chardet

# %%
# look at the first thousand bytes to guess the character encoding
with open("C:/Users/User/Downloads/Aircrash_Operators1.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(1000))

# check what the character encoding might be
print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
# read in the file with the encoding detected by chardet
operators = pd.read_csv("C:/Users/User/Downloads/Aircrash_Operators1.csv", encoding='ISO-8859-1')

# look at the first few lines
operators.head()
# Out:
#                                                 Name  Fatalities
# 0          Aeroflot - Russian International Airlines       11308
# 1        United States Air Force - USAF (since 1947)        8207
# 2                              Royal Air Force - RAF        7988
# 3  United States Army Air Forces - USAAF (1941-1947)        6904
# 4                           United States Navy - USN        4087

# %%
#Ok, it works
operators.to_csv("Aircrash_Operators1.csv") #our dataset will be saved as UTF-8 by default!)
operators.head()
# Out:
#                                                 Name  Fatalities
# 0          Aeroflot - Russian International Airlines       11308
# 1        United States Air Force - USAF (since 1947)        8207
# 2                              Royal Air Force - RAF        7988
# 3  United States Army Air Forces - USAAF (1941-1947)        6904
# 4                           United States Navy - USN        4087

# %%
operators.tail()
# Out:
#                                                 Name  Fatalities
# 95  Hellenic Air Force - Elleniki Polemiki Aeroporia         257
# 96                                         Arrow Air         256
# 97                                          Gulf Air         255
# 98   SAM Colombia - Sociedad Aeronáutica de Medellín         255
# 99                     Trans-Canada Air Lines - TCAL         254

# %% [markdown]
# ## Back to Visualization

# %%
operators_top_10 = operators.sort_values(by='Fatalities', ascending=False).head(20)

plt.figure(figsize=(15,10))
sns.barplot(y=operators_top_10.Name, x="Fatalities", data=operators_top_10, palette="gist_heat", orient='h')
plt.xlabel('Fatalities', fontsize=11)
plt.ylabel('Operator', fontsize=11)
plt.title('Total Fatalities by Opeartor (TOP 20)', loc='Center', fontsize=14)
plt.show()

# %% [markdown]
# Despite the military air activities for transportation, reconnaissance, surveillance, medium and heavy bombardment and logistic support during the Second World War, Vietnam War, Korean War, Cuban missile crisis and the cold war in general, it looks like Aeroflot has the most number of accident for all the time. But my dataset doesn't consist of amount of civilian/military flights and passengers by airlines. If Aeroflot has the largest number of crashes, it might have the largest amount of flights.
#
# While performing this very basic EDA, I encoded and visualized up-to-date data from Airplane Crashes Dataset from B3A. Looking forward for your feedback. Thanks a lot.
#
# Have a great day.
#
# Sencer
